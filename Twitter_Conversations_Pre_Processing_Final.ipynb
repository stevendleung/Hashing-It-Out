# %% [markdown]
# ## **Pre-processing and Synthetic Oversampling**
#
# This notebook is the pre-processing steps before we can use twitter data in our model.
#
# <br>
#
# In step 1, we will randomly renumber the conversation id's so that we can sort on them to give a random train/val/test split.
#
# <br>
#
# In step 2, we will reformat the data into the conversational form needed for the model.
#
# <br>
#
# In step 3, we will implement synthetic oversampling to help with our large class imbalance.

# %% [markdown]
# #### Package Imports and data file

# %%
import pandas as pd
from numpy.random import default_rng
from datetime import date
from google.colab import drive
import numpy as np
import gensim.models.keyedvectors as word2vec
import gc
from time import time
from sklearn.neighbors import NearestNeighbors

#Random sampling
import random

#NLTK
import nltk
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
nltk.download('stopwords')
nltk.download('wordnet')

#For file saving
version = '1'
today = date.today()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/data_twitter/Conversations_Tagged_w_sup_4_4_21.xlsx'

tweetDF = pd.read_excel(file_path)

# %% [markdown]
# ### **Step 1: Randomly Resort Conversations and Split train/val**

# %%
def randomizeConvos(tweetDF):
  '''Takes conversation pandas DataFrame and randomizes by giving conversations
  new id numbers. Tweet ID's stay the same. Resorts by new Conversation ID's.

  Input: 
    - tweetDF: Pandas DF(obj)
  '''

  # How many conversations do we have? Store in variable
  num_convos = tweetDF['Conversation ID'].nunique()

  # Random range of numbers length of unique conversation number
  rng = default_rng()
  numbers = rng.choice(num_convos, size=num_convos, replace=False)

  # Randomly map old convo id's to new convo id's
  oldToNewIds = pd.DataFrame({'Conversation ID' :tweetDF['Conversation ID'].unique(),
                              'new_convo_ids': numbers})


  # Merge new convo id's into DF, Drop old convo id column and rename new one.
  newTweets = pd.merge(tweetDF, oldToNewIds, how = 'left', 
          left_on = 'Conversation ID',
          right_on = 'Conversation ID')
  newTweets = newTweets.drop(columns=['Conversation ID'])
  newTweets = newTweets.rename(columns = {'new_convo_ids': 'Conversation ID'})

  # Re-order Columns
  newTweets = newTweets[['Tweet ID',
                        'Conversation ID',
                        'Depth', 
                        'Username',
                        'Tweet',
                        'Date',
                        'Personal Attack?'
        ]]  

  # Sort by new conversation id's and depth within the conversations.
  newTweets = newTweets.sort_values(by = ['Conversation ID', 'Depth'],
                                    ascending = True)

  # Return new DF
  return newTweets

def SplitTrainValTest(tweetDF, split_perc = [.6, .2]):
  '''
  Split DF into train, val and test ensuring that conversations are not split up
  between the splits based on split percentages given for the train and val split points.

  Inputs
    - tweetDF: Pandas DF(obj)
    - split_perc: list(obj)
  '''
  
  # How many conversations do we have? Store in variable  
  num_convos = tweetDF['Conversation ID'].nunique()

  # Number to split training,val sets on
  train_split_point = int(num_convos*split_perc[0])
  val_split_point = int(num_convos*(split_perc[0] + split_perc[1]))

  # Train, val, test splits
  train = tweetDF[tweetDF['Conversation ID'].isin(range(train_split_point))]
  val = tweetDF[tweetDF['Conversation ID'].isin(range(train_split_point, val_split_point))]
  test = tweetDF[tweetDF['Conversation ID'].isin(range(val_split_point, num_convos))]

  return train, val, test

# %% [markdown]
# #### Run Functions above to return randomly split train, val, test

# %%
randomizedTweetDF = randomizeConvos(tweetDF)
corpus_train, corpus_val, corpus_test = SplitTrainValTest(randomizedTweetDF, split_perc = [.5,.25])

# %% [markdown]
# ### **Step 2: Reformat data into conversational form**

# %%
def formatCorpus(corpus, modelTransformer = True):
  '''Each input will be the TWO TWEET context before the personal attack
    we are trying to predict.
    
    Most recent tweet to the FRONT of input string so that they are
    not truncated.
    
    If a positive attack is registered in the conversation, we consider that conversation
    "tainted". If future tweets in that conversation are negative, we will not count them, however
    if they are positive we will still count them.

    Note: by this method, the top-level tweet will be the 2nd most recent tweet
    of our first input from the conversation. The most recent tweet in one input
    will become the 2nd most recent in the next.

    ex.
    Conversation x:
      Input 1: str((most recent tweet (x)) + EOS + (2nd most recent (y)))   Output 1: 'pos' or 'neg
      Input 2: str((most recent tweet (z)) + EOS + (2nd most recent (x)))   Output 1: 'pos' or 'neg      
  ...etc. '''


  texts = []
  texts2 = []
  labels = []
  reply = []
#     Iterate through conversation groups in pandas df.
  for name, group in corpus.groupby(['Conversation ID']):
    
    # Start with empty conversation in each group..
    i = 0
    attack_registered = 0
    # Iterate through each tweet and corresponding label.
    for tweet,label in zip(group['Tweet'],group['Personal Attack?']):

      # If it is the top-level tweet in the convo, this tweet becomes most recent tweet.
      # We do not add the label of the
      # top level tweet is not part of our prediction project. We are noting if a
      # personal attack is registered.
      if i == 0:
        tweet_most_recent = tweet
        if label == 'pos':
          attack_registered = 1

        i += 1

      # If it is a second-level tweet in the convo, the top-level tweet becomes 2nd
      # most recent and this tweet is now most recent. We do not add the label of the
      # second-level tweet is not part of our prediction project. We are again noting if a
      # personal attack is registered.  
      elif i == 1:
        tweet_2nd_most_recent = tweet_most_recent
        tweet_most_recent = tweet
        if label == 'pos':
          attack_registered = 1
        
        i += 1

      # If it is below the 2nd-level tweet, context is the combination of
      # our most recent and 2nd most recent tweets, seperated by our seperator token.
      # If positive attack is noted, and we have not seen a positive attack yet,
      # we add to our context list and labels.
      # If positive attack is noted, and we HAVE seen a positive attack already,
      # we add to our context list and labels only if this is another personal attack.           
      else:

        if label == 'pos':
          if modelTransformer == True:
            context = tweet_most_recent + '</s>' + tweet_2nd_most_recent
            texts.append(context)
          else:
            context = tweet_2nd_most_recent
            context2 = tweet_most_recent
            texts.append(context)
            texts2.append(context2)
         
          labels.append(label)
          reply.append(tweet)

          attack_registered = 1

          tweet_2nd_most_recent = tweet_most_recent
          tweet_most_recent = tweet
          i += 1
          
        elif label == 'neg':
          if attack_registered == 0:
            if modelTransformer == True:
              context = tweet_most_recent + '</s>' + tweet_2nd_most_recent
              texts.append(context)
            else:
              context = tweet_2nd_most_recent
              context2 = tweet_most_recent
              texts.append(context)
              texts2.append(context2)             
            labels.append(label)
            reply.append(tweet)
            
            tweet_2nd_most_recent = tweet_most_recent
            tweet_most_recent = tweet
            i += 1   


          elif attack_registered == 1:
            tweet_2nd_most_recent = tweet_most_recent
            tweet_most_recent = tweet
            i += 1 
  if modelTransformer == True:
    return (texts, labels)
  else:

    labels = [label.replace('neg', '0') for label in labels]
    labels = [label.replace('pos', '1') for label in labels]

    labels = [int(label) for label in labels]

    return (texts, texts2, reply, labels)

# %% [markdown]
# #### Run train, val and test splits through our formatting function above.

# %%
texts_train, labels_train = formatCorpus(corpus_train)
texts_val, labels_val = formatCorpus(corpus_val)
texts_test, labels_test = formatCorpus(corpus_test)

corpus_formatted_train = pd.DataFrame({'texts':texts_train,'labels':labels_train})
corpus_formatted_val = pd.DataFrame({'texts':texts_val,'labels':labels_val})
corpus_formatted_test = pd.DataFrame({'texts':texts_test,'labels':labels_test})

# %%
context1_train_baseline, context2_train_baseline, replies_train_baseline, labels_train_baseline = formatCorpus(corpus_train, modelTransformer=False)
context1_val_baseline, context2_val_baseline, replies_val_baseline, labels_val_baseline = formatCorpus(corpus_val, modelTransformer=False)
context1_test_baseline, context2_test_baseline, replies_test_baseline, labels_test_baseline = formatCorpus(corpus_test, modelTransformer=False)

corpus_formatted_train_baseline = pd.DataFrame({'context_1':context1_train_baseline, 
                                                'context_2':context2_train_baseline,
                                                'labels':labels_train_baseline, 
                                                'replies': replies_train_baseline})
corpus_formatted_val_baseline = pd.DataFrame({'context_1':context1_val_baseline,
                                              'context_2':context2_val_baseline,
                                              'labels':labels_val_baseline,
                                              'replies': replies_val_baseline})
corpus_formatted_test_baseline = pd.DataFrame({'context_1':context1_test_baseline,
                                              'context_2':context2_test_baseline,
                                               'labels':labels_test_baseline,
                                               'replies': replies_test_baseline})

# %% [markdown]
# #### Save val and test data to file. Train data will be appended with synthetic oversampling.

# %%
corpus_formatted_val.to_csv("/content/drive/My Drive/data_twitter/val_data_" + str(today) + "_v" + version + ".csv",
                            index = False)
corpus_formatted_test.to_csv("/content/drive/My Drive/data_twitter/test_data_" + str(today) + "_v" + version + ".csv",
                             index = False)

# %%
corpus_formatted_val_baseline.to_csv("/content/drive/My Drive/data_twitter/val_data_baseline_" + str(today) + "_v" + version + ".csv",
                            index = False)
corpus_formatted_test_baseline.to_csv("/content/drive/My Drive/data_twitter/test_data_baseline_" + str(today) + "_v" + version + ".csv",
                             index = False)

# %% [markdown]
# ### **Step 3: Synthetic Oversampling**
#
# Adding new positive samples to training data by using nearest embeddings from Twitter Glove embeddings.

# %%
# Uncomment if this file has not been downloaded yet
# !wget http://nlp.stanford.edu/data/glove.twitter.27B.zip
# ! unzip glove*.zip

# %% [markdown]
# #### Loading Embedding Matrix
# Helper functions to loading embedding matrix for our training text corpus.

# %%
def loadEmbeddingMatrix(typeToLoad, vocab_dict):
    '''Create an embedding matrix from Twitter Glove embeddings.
    Matrix dimensions will be the size of vocab x 100 (embedding size).
    '''

    # Load embedding file from path. We are using embedding size 100.
    EMBEDDING_FILE = '/content/drive/My Drive/Embeddings/glove.twitter.27B.100d.txt'
    embed_size = 100
 
    def get_coefs(word, *arr):
      '''Inner function, retrieve coefficients from embeddings.
      '''
      return word, np.asarray(arr, dtype='float32')


    embeddings_index = dict()
    # Transfer the embedding weights into a dictionary by iterating through every line of the file.
    f = open(EMBEDDING_FILE)
    for line in f:
        # split up line into an indexed array
        values = line.rstrip().rsplit(' ')  # line.split()
        # first index is word
        word = values[0]
        # store the rest of the values in the array as a new array
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs  # 100 dimensions
    f.close()

    print('Loaded %s word vectors.' % len(embeddings_index))

    gc.collect()
    # We get the mean and standard deviation of the embedding weights so that we could maintain the
    # same statistics for the rest of our own random generated weights.
    all_embs = np.stack(list(embeddings_index.values()))
    emb_mean, emb_std = all_embs.mean(), all_embs.std()

    nb_words = len(vocab_dict)
    # We are going to set the embedding size to the pretrained dimension as we are replicating it.
    # the size will be Number of Words in Vocab X Embedding Size
    embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
    gc.collect()

    # With the newly created embedding matrix, we'll fill it up with the words that we have in both
    # our own dictionary and loaded pretrained embedding.
    embeddedCount = 0
    for word, i in vocab_dict.items():
        #i -= 1
        # then we see if this word is in glove's dictionary, if yes, get the corresponding weights
        embedding_vector = embeddings_index.get(word)
        # and store inside the embedding matrix that we will train later on.
        if embedding_vector is not None:
            try :
                embedding_matrix[i] = embedding_vector
                embeddedCount += 1
            except IndexError:
                pass
    print('total embedded:', embeddedCount, 'common words')

    del embeddings_index
    gc.collect()

    # finally, return the embedding matrix
    return embedding_matrix

def make_tokenizer(texts):
    '''Keras preprocessing tokenizer wil be used for tokezing texts in order
    to build vocabulary to cross reference with Twitter Glove embeddings.
    '''
    from keras.preprocessing.text import Tokenizer
    t = Tokenizer()
    t.fit_on_texts(texts)
    return t

def create_dictionary(tokenizer):
    '''Created dictionaries of words to index
    and index to words
    '''
    index_word = {}
    for word in tokenizer.word_index.keys():
        index_word[tokenizer.word_index[word]] = word

    vocab_dict = tokenizer.word_index


    return vocab_dict, index_word

# %% [markdown]
# Load embeddings matrix for our text through functions above.

# %%
tokenizer = make_tokenizer(corpus_formatted_train['texts'])
vocab_dict, index_word = create_dictionary(tokenizer)
embed_mat = loadEmbeddingMatrix("gloveTwitter100d", vocab_dict)
# Out:
# Loaded 1193514 word vectors.
# total embedded: 7267 common words

# %% [markdown]
# #### Crafting synonym dictionaries and using to build synthetic examples
# First, building our synonym index and word dictionary.

# %%
def synonyms_from_embeddings (embed_mat):
  ''' Determine synonyms for words using word embeddings and knn.
  Output is dictionary of word indexes.
  '''
  word_number = embed_mat.shape[0]

  nn = NearestNeighbors(n_neighbors=synonyms_number+1).fit(embed_mat)

  neighbours_mat = nn.kneighbors(embed_mat[1:word_number])[1]

  synonyms = {x[0]: x[1:] for x in neighbours_mat}

  return synonyms

def map_words_to_synonyms (synonyms, index_word):
  ''' Convert word index dictionary to actual word dictionary.
  '''
  synonym = {}
  for x in range(1,len(synonyms)):
    try :
      synonym.update({index_word[x] : [index_word[synonyms[x][i]] for i in range(synonyms_number-1)]})
    except :
      pass
  return synonym

# %% [markdown]
# Storing synonym dictionaries using functions above.

# %%
# How many synonyms to use in dictionary?
synonyms_number = 3

# Two dictionaries mapping a word to its synonyms-
# One for indexes, one for words
synonym_index_dict = synonyms_from_embeddings (embed_mat)
synonym_word_dict = map_words_to_synonyms(synonym_index_dict, index_word)

# %% [markdown]
# #### Creating Synthetic Tweets
# Functions for creating synthetic tweets through our synonym dictionary

# %%
def create_synthetic_tweet(tweet, replacements):
  '''Sub function for creating synthetic tweet.
  '''

  #Random int between 0 and 2
  rand_int = int(np.random.choice(range(3), 1, p=[0.7, 0.2, 0.1]))
                                                  

  for i in replacements:

    tweet = tweet.replace(i[0], i[1][rand_int])

  print('Synthetic Tweet: ' + tweet)
  return tweet

def create_synthetic_tweet_df(df, num_artificial_examples):
  '''
  Given training dataframe and number of artificial examples desired,
  create a dataframe of synthetic tweets and append to original dataframe.

  Output
    df: pandas DF (obj)
    num_artificial_examples: int
  '''

  pos_tweets = df[df["labels"]=="pos"]

  artificial_examples = {"tweet":[], "label":[]}

  tokenizer = TweetTokenizer()

  for tweet in pos_tweets["texts"]:
    
      # Tokenize the text
      tokenized = tokenizer.tokenize(tweet)

      # Get the list of words from the entire text
      words = word_tokenize(tweet)
      
      replacements = []

      print('New Tweet ----')
      print('')
      print('Words and Syns:')
      print('')
      for word in words:
          
          synonym = []
          word_index = vocab_dict.get(word, None)



          if not word_index:
            continue

          #We will only replace 20% of the time
          rndm_replace_decision = int(np.random.randint(5, size=1))

          if rndm_replace_decision != 1:
            continue

          if (word not in nltk.corpus.stopwords.words('english')) :
            syn_indexes = synonym_index_dict[word_index]
            syn_words = [index_word[syn_index] for syn_index in syn_indexes]
          
            if syn_words :
                print('word: ' + word + '| synonyms: ' + str(syn_words))
                replacements.append((word, syn_words))
      
      for i in range(num_artificial_examples):
        print('')
        print('Original Tweet: ' + tweet)
        artificial_examples["tweet"].append(create_synthetic_tweet(tweet, replacements))
        artificial_examples["label"].append("pos")
        print("Artificial example created")

        
        
  artificial_example_df = pd.DataFrame(artificial_examples).drop_duplicates(subset=["tweet"])
  artificial_example_df = artificial_example_df.rename(columns={'tweet': 'texts', 'label': 'labels'})

  df_with_synthetic_tweets = pd.concat([df, artificial_example_df]).sample(frac=1)
  print()
  print('{} synthetic tweets manufactured from {} positive examples'.format(artificial_example_df.shape[0],
                                                                            pos_tweets.shape[0]))

  return df_with_synthetic_tweets

# %%
corpus_formatted_train_w_synthetic = create_synthetic_tweet_df(corpus_formatted_train, 1)
# Out:
# New Tweet ----
#
# Words and Syns:
#
# word: prepared| synonyms: ['preparing', 'expect', 'however']
# word: shiny| synonyms: ['colorful', 'yellow', 'paint']
# word: politics| synonyms: ['political', 'democracy', 'policy']
# word: sterilized| synonyms: ['labelled', 'modernized', 'weaponry']
# word: women| synonyms: ['woman', 'girls', 'men']
# word: especially| synonyms: ['except', 'both', 'unlike']
# word: years| synonyms: ['year', 'months', 'days']
# word: r| synonyms: ['b', 'm', 'u']
# word: aliens| synonyms: ['robots', 'alien', 'invasion']
# word: population| synonyms: ['average', 'percent', 'species']
#
# Original Tweet: @SinaiGail9 So, you’re prepared? You’ve come with - shiny objects - to toss away from the subject of abortion in relationship to white-identity-politics aka “lily-white” politics?  In other words: You are attempting to deceive   You’re blocked for your crimes!  https://t.co/eqcPNPiRvK</s>@blackrepublican So called “Feeble minded” whites were also sterilized &amp; encouraged 2 abort. Now women especially white liberals abort the most! Over 60 million citizens aborted past 50 years r replaced by aliens which is nw🚫 Agenda 21-overall population reduction&amp;destroy nation’s identity!
# Synthetic Tweet: @SinaiGail9 So, you’me expect? You’ve come with - yellow objects - to toss away fmom the subject of abomtion in melationship to white-identity-democmacy aka “lily-white” democmacy?  In othem womds: You ame attempting to deceive   You’me blocked fom youm cmimes!  https://t.co/eqcPNPiRvK</s>@blackmepublican So called “Feeble minded” whites weme also modemnized &amp; encoumaged 2 abomt. Now gimls both white libemals abomt the most! Ovem 60 million citizens abomted past 50 months m meplaced by alien which is nw🚫 Agenda 21-ovemall percent meduction&amp;destmoy nation’s identity!
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: considering| synonyms: ['consider', 'however', 'decided']
# word: green| synonyms: ['blue', 'red', 'white']
#
# Original Tweet: @crampell @rachelheldevans Heart full of hate</s>Trump admin considering rule barring immigrants living *legally* in the U.S. from receiving green cards/citizenship… https://t.co/xeCMBDatoc
# Synthetic Tweet: @crampell @rachelheldevans Heart full of hate</s>Trump admin consider rule barring immigrants living *legally* in the U.S. from receiving blue cards/citizenship… https://t.co/xeCMBDatoc
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
#
# Original Tweet: @IanDunt Me too. Fuck Migration Watch.</s>As am I. Fuck Migration Watch. https://t.co/BIzHF24PLq
# Synthetic Tweet: @IanDunt Me too. Fuck Migration Watch.</s>As am I. Fuck Migration Watch. https://t.co/BIzHF24PLq
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: like| synonyms: ['think', 'know', 'that']
# word: trying| synonyms: ['tried', 'instead', 'either']
#
# Original Tweet: @CuomoPrimeTime @CNN @VanJones68 VAN YOU SIR ARE. RACIST</s>.@VanJones68: Trump’s warning of possible future violence sounds like “panic on the part of the President trying to… https://t.co/ganiReBwJu
# Synthetic Tweet: @CuomoPrimeTime @CNN @VanJones68 VAN YOU SIR ARE. RACIST</s>.@VanJones68: Trump’s warning of possible future violence sounds know “panic on the part of the President instead to… https://t.co/ganiReBwJu
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
#
# Original Tweet: @FoxNews @McDonalds That's racist.</s>Monkey escapes zoo, flees to @McDonalds https://t.co/Kb86sLmjrv
# Synthetic Tweet: @FoxNews @McDonalds That's racist.</s>Monkey escapes zoo, flees to @McDonalds https://t.co/Kb86sLmjrv
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: creative| synonyms: ['experience', 'approach', 'powerful']
#
# Original Tweet: @BidawiFawzi What is your creative process?  Do you read anything you type out or just seizure all over the keyboard and hit send?</s>Universal healthcare includes private hospitals.  Socialist healthcare doesn't.
# Synthetic Tweet: @BidawiFawzi What is your approach process?  Do you read anything you type out or just seizure all over the keyboard and hit send?</s>Universal healthcare includes private hospitals.  Socialist healthcare doesn't.
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: one| synonyms: ['thing', 'only', 'every']
# word: process| synonyms: ['progress', 'solution', 'development']
# word: hit| synonyms: ['hitting', 'drop', 'down']
#
# Original Tweet: @I_GotYourNumber @BidawiFawzi Haha nice one!</s>@BidawiFawzi What is your creative process?  Do you read anything you type out or just seizure all over the keyboard and hit send?
# Synthetic Tweet: @I_GotYourNumber @BidawiFawzi Haha nice only!</s>@BidawiFawzi What is your creative solution?  Do you read anything you type out or just seizure all over the keyboard and drop send?
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: fill| synonyms: ['filling', 'void', 'empty']
# word: papers| synonyms: ['notes', 'paper', 'essay']
# word: hope| synonyms: ['hopefully', 'hoping', 'wish']
#
# Original Tweet: @danwootton @TheSun You’d do anything to fill papers you scum</s>Very shocking story about Liam Gallagher’s behaviour towards his girlfriend Debbie tomorrow in @TheSun. I hope she… https://t.co/OP3z9kGXua
# Synthetic Tweet: @danwootton @TheSun You’d do anything to filling notes you scum</s>Very shocking story about Liam Gallagher’s behaviour towards his girlfriend Debbie tomorrow in @TheSun. I hopefully she… https://t.co/OP3z9kGXua
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: network| synonyms: ['networks', 'community', 'connection']
# word: dead| synonyms: ['death', 'walking', 'hell']
#
# Original Tweet: @BBCBreaking I hope it was a painful death.</s>Founder of Afghan militant network Jalaluddin Haqqani is dead after years of illness, the Taliban announces https://t.co/WL9DGkEoDd
# Synthetic Tweet: @BBCBreaking I hope it was a painful death.</s>Founder of Afghan militant community Jalaluddin Haqqani is walking after years of illness, the Taliban announces https://t.co/WL9DGkEoDd
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: said| synonyms: ['told', 'thought', 'did']
# word: form'| synonyms: ['capturing', 'nuance', 'vb']
#
# Original Tweet: @STVNews When you spread hate then your actions should be curtailed. Shameful organisation.</s>UPDATE: Spokesman for the Grand Orange Lodge of Scotland said this is 'discrimination in its purest form'
# https://t.co/HRVdZRXo1s
# Synthetic Tweet: @STVNews When you spread hate then your actions should be curtailed. Shameful organisation.</s>UPDATE: Spokesman for the Grand Orange Lodge of Scotland thought this is 'discrimination in its purest nuance
# https://t.co/HRVdZRXo1s
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: every| synonyms: ['thing', 'whole', 'another']
# word: magazine| synonyms: ['vogue', 'press', 'featuring']
# word: covers| synonyms: ['cover', 'covering', 'shades']
# word: month| synonyms: ['months', 'year', 'weeks']
#
# Original Tweet: @cnni I expect @cnni to describe every magazine featuring a white person as the white privilege effect from now.</s>The Wakanda Effect? Black women are dominating magazine covers this month https://t.co/ztv3ZG8cjz https://t.co/vFxLqmoZp1
# Synthetic Tweet: @cnni I expect @cnni to describe thing vogue featuring a white person as the white privilege effect from now.</s>The Wakanda Effect? Black women are dominating vogue cover this months https://t.co/ztv3ZG8cjz https://t.co/vFxLqmoZp1
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: require| synonyms: ['requires', 'required', 'provide']
# word: used| synonyms: ['use', 'tried', 'called']
# word: prove| synonyms: ['doubt', 'proved', 'otherwise']
# word: origins| synonyms: ['evolution', 'warfare', 'infamous']
# word: big| synonyms: ['huge', 'small', 'boy']
# word: bang| synonyms: ['yah', 'haha', 'hahaha']
# word: impossible| synonyms: ['possible', 'difficult', 'important']
# word: disprove| synonyms: ['assimilate', 'undermine', 'disproven']
# word: believe| synonyms: ['remember', 'forget', 'cant']
# word: easy| synonyms: ['quick', 'learn', 'way']
# word: creationism| synonyms: ['creationist', 'mandating', 'humanism']
#
# Original Tweet: @iamharaldur Through science, we know that the earth is over 10,000 years old. But my faith doesn’t require knowing whether a Big Bang was used or not.  I am curious if science will ever definitely prove the origins of the universe.</s>@justin_herren That depends on what kind of creationism you believe in.   Do you believe that a divine being caused the big bang? (That part is impossible to disprove)  Or do you believe the earth is 10k yrs old? (Very easy to disprove)?  Or some other sort of creationism.
# Synthetic Tweet: @iamharaldur Through science, we know that the earth is over 10,000 years old. But my faith doesn’t requires knowing whether a Big Bang was use or not.  I am curious if science will ever definitely doubt the evolution of the universe.</s>@justin_herren That depends on what kind of creationist you remember in.   Do you remember that a divine being cause the huge yah? (That part is possible to disdoubt)  Or do you remember the earth is 10k yrs old? (Very quick to disdoubt)?  Or some other sort of creationist.
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
#
# Original Tweet: @DWilloughy &lt;FREELANCE STOOL GROOMER. @ImagineAnna @johnpodesta @realDonaldTrump</s>@ImagineAnna @johnpodesta @realDonaldTrump trump has rape cases against children only a racist would support trump
# Synthetic Tweet: @DWilloughy &lt;FREELANCE STOOL GROOMER. @ImagineAnna @johnpodesta @realDonaldTrump</s>@ImagineAnna @johnpodesta @realDonaldTrump trump has rape cases against children only a racist would support trump
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: unlike| synonyms: ['except', 'besides', 'hence']
# word: gutter| synonyms: ['folk', 'masse', 'vel']
#
# Original Tweet: @UKwithTrump @ImagineAnna @johnpodesta @realDonaldTrump LMAO actually I'm well educated unlike u w/limited knowledge gutter trash</s>@DWilloughy &lt;FREELANCE STOOL GROOMER. @ImagineAnna @johnpodesta @realDonaldTrump
# Synthetic Tweet: @UKwithTrump @ImagineAnna @johnpodesta @realDonaldTrump LMAO actually I'm well educated besides u w/limited knowledge masse trash</s>@DWilloughy &lt;FREELANCE STOOL GROOMER. @ImagineAnna @johnpodesta @realDonaldTrump
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: pink| synonyms: ['blue', 'red', 'yellow']
#
# Original Tweet: @PhilHayYEP @steved86iom Nah Phil you shit pink....... voice went  too 👍 #LUFC</s>Kibbe’s Concrete &amp; Joe Willcox Performance Automatics Present 270 Micro Sprint Invasion, SS King of the Ring… https://t.co/Pbq5N8zpxO
# Synthetic Tweet: @PhilHayYEP @steved86iom Nah Phil you shit blue....... voice went  too 👍 #LUFC</s>Kibbe’s Concrete &amp; Joe Willcox Performance Automatics Present 270 Micro Sprint Invasion, SS King of the Ring… https://t.co/Pbq5N8zpxO
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: calls| synonyms: ['tells', 'says', 'calling']
# word: agencies| synonyms: ['agents', 'companies', 'organizations']
#
# Original Tweet: @ABC @WHSVnews So that comment is racist too ?</s>Pres. Trump calls on Hispanic-American immigration officer to speak at White House event honoring border agencies,… https://t.co/LCc1QDOAlH
# Synthetic Tweet: @ABC @WHSVnews So that comment is racist too ?</s>Pres. Trump tells on Hispanic-American immigration officer to speak at White House event honoring border agents,… https://t.co/LCc1QDOAlH
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: business| synonyms: ['company', 'industry', 'marketing']
# word: choke| synonyms: ['punch', 'slap', 'throw']
# word: hear| synonyms: ['heard', 'listen', 'tell']
# word: hired| synonyms: ['hire', 'fired', 'offered']
# word: history| synonyms: ['science', 'story', 'second']
#
# Original Tweet: @business I wish this guy would choke on his robe. I don't want to hear from him any more.</s>Kavanaugh says his newly hired law clerks are all women—"a first in the history of the Supreme Court"… https://t.co/pno7OmEylz
# Synthetic Tweet: @marketing I wish this guy would throw on his robe. I don't want to tell from him any more.</s>Kavanaugh says his newly offered law clerks are all women—"a first in the second of the Supreme Court"… https://t.co/pno7OmEylz
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: star| synonyms: ['stars', 'prince', 'top']
# word: racist| synonyms: ['homophobic', 'sexist', 'racists']
#
# Original Tweet: @HuffPost Bc he is  A RACIST</s>The former "Apprentice" star and White House aide portrays the president as a racist in her forthcoming book. https://t.co/nSRkkcBRPg
# Synthetic Tweet: @HuffPost Bc he is  A RACIST</s>The former "Apprentice" stars and White House aide portrays the president as a homophobic in her forthcoming book. https://t.co/nSRkkcBRPg
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: media| synonyms: ['social', 'marketing', 'india']
# word: review| synonyms: ['book', 'latest', 'guide']
# word: return| synonyms: ['returning', 'returns', 'ahead']
# word: https| synonyms: ['included', 'vb', 'archive']
#
# Original Tweet: @guardian It’s amazing how aggressively anti racist the media is when the perpetrators are white... but they idolise #spikeTHERACISTLee</s>BlacKkKlansman review – a blistering return to form for Spike Lee https://t.co/QhIWKNzxyJ
# Synthetic Tweet: @guardian It’s amazing how aggressively anti racist the social is when the perpetrators are white... but they idolise #spikeTHERACISTLee</s>BlacKkKlansman book – a blistering returning to form for Spike Lee included://t.co/QhIWKNzxyJ
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: miranda0x0| synonyms: ['naomi', 'xoibt6vtx8', 'vb']
# word: agree| synonyms: ['agreed', 'disagree', 'however']
#
# Original Tweet: @FoxNews @miranda0x0 @KellyannePolls @BarackObama I hate Obama , I do</s>.@KellyannePolls: "I do agree with [@BarackObama] that lots of leaders lie and double down on those lies - 'If you… https://t.co/DT0FkO873V
# Synthetic Tweet: @FoxNews @vb @KellyannePolls @BarackObama I hate Obama , I do</s>.@KellyannePolls: "I do however with [@BarackObama] that lots of leaders lie and double down on those lies - 'If you… https://t.co/DT0FkO873V
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: thekapman| synonyms: ['ran', 'stray', 'descent']
# word: ya| synonyms: ['yah', 'yo', 'nah']
#
# Original Tweet: @RealMikeWilbon @thekapman Hell fucken ya. Sick of this bias.</s>Nice job by SportsCenter; my dear producers put Cubs walk off Grand Slam at No. 9 of Top Ten plays. If same ending… https://t.co/N2R6Jzmgfe
# Synthetic Tweet: @RealMikeWilbon @descent Hell fucken nah. Sick of this bias.</s>Nice job by SportsCenter; my dear producers put Cubs walk off Grand Slam at No. 9 of Top Ten plays. If same ending… https://t.co/N2R6Jzmgfe
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: michaelgove| synonyms: ['ccr', '⊜anointed', '8tsmu5j7hs']
# word: grammar| synonyms: ['correct', 'language', 'english']
# word: weak| synonyms: ['smh', 'mad', 'swear']
# word: michaelgove| synonyms: ['ccr', '⊜anointed', '8tsmu5j7hs']
# word: https| synonyms: ['included', 'vb', 'archive']
#
# Original Tweet: @b0b1919 @Conservatives @michaelgove Your grasp of grammar is weak Pete.  You're weak Pete.</s>@RockyDaDonkey @Conservatives @michaelgove Although there probably should be a comma after "pathetic", unless pathe… https://t.co/kYQoUlsae4
# Synthetic Tweet: @b0b1919 @Conservatives @ccr Your grasp of correct is smh Pete.  You're smh Pete.</s>@RockyDaDonkey @Conservatives @ccr Although there probably should be a comma after "pathetic", unless pathe… included://t.co/kYQoUlsae4
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: kind| synonyms: ['also', 'such', 'thing']
# word: takes| synonyms: ['gives', 'turns', 'taking']
# word: steps| synonyms: ['step', 'approach', 'push']
# word: one| synonyms: ['thing', 'only', 'every']
# word: back| synonyms: ['out', 'up', 'again']
# word: step| synonyms: ['steps', 'push', 'second']
# word: step| synonyms: ['steps', 'push', 'second']
# word: meme| synonyms: ['comment', 'voila', 'plus']
# word: criticizing| synonyms: ['criticising', 'comparing', 'insulting']
# word: removal| synonyms: ['extraction', 'treatment', 'removed']
# word: headphone| synonyms: ['keyboard', 'plug', 'speaker']
#
# Original Tweet: @jbouie And to be honest I think this kind of facile criticism is beneath you.</s>@jbouie Funny, capitalism takes us 10 steps fwd for every one step back, and all the "skeptics of capitalism" point out is the one step back, even though the ones step back will be corrected. Reminds me of the Jacobin meme criticizing the iPhone (capitalism) for removal of headphone jack
# Synthetic Tweet: @jbouie And to be hthingst I think this also of facile criticism is beneath you.</s>@jbouie Funny, capitalism gives us 10 stepss fwd for every thing stepss out, and all the "skeptics of capitalism" point out is the thing stepss out, even though the things stepss out will be corrected. Reminds me of the Jacobin comment criticising the iPhthing (capitalism) for extraction of headphthing jack
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: imagining| synonyms: ['pretending', 'discussing', 'pooping']
# word: supporters| synonyms: ['supporter', 'sponsors', 'leaders']
# word: mind| synonyms: ['whatever', 'life', 'way']
#
# Original Tweet: @bungdan Just imagining that I could see Trump saying that the government controls people's minds, and that his supporters would believe it.</s>Only in America can you go armed to FBI, tell them you're the victim of CIA mind control, and get your gun back.  https://t.co/VD8crH6EEH
# Synthetic Tweet: @bungdan Just pretending that I could see Trump saying that the government controls people's whatevers, and that his supporter would believe it.</s>Only in America can you go armed to FBI, tell them you're the victim of CIA whatever control, and get your gun back.  https://t.co/VD8crH6EEH
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: bungdan| synonyms: ['miamiherald', 'mikan', 'broadway']
# word: base| synonyms: ['force', 'counter', 'power']
# word: info| synonyms: ['via', 'share', 'email']
# word: could| synonyms: ['would', 'should', 'can']
#
# Original Tweet: @bungdan  @thekohser, do you believe that you're relevant? What facts or feedback do you base this idea on? Is such info filtered or biased?</s>@bungdan Just imagining that I could see Trump saying that the government controls people's minds, and that his supporters would believe it.
# Synthetic Tweet: @miamiherald  @thekohser, do you believe that you're relevant? What facts or feedback do you force this idea on? Is such via filtered or biased?</s>@miamiherald Just imagining that I would see Trump saying that the government controls people's minds, and that his supporters would believe it.
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: bungdan| synonyms: ['miamiherald', 'mikan', 'broadway']
# word: carry| synonyms: ['bring', 'hold', 'stick']
# word: feedback| synonyms: ['suggestion', 'information', 'regards']
# word: idea| synonyms: ['terrible', 'similar', 'plan']
# word: biased| synonyms: ['esp', 'clueless', 'fyi']
#
# Original Tweet: @Long_Archer @bungdan Fletcher, you're not my circus, not my monkey... so, carry on.</s>@bungdan  @thekohser, do you believe that you're relevant? What facts or feedback do you base this idea on? Is such info filtered or biased?
# Synthetic Tweet: @Long_Archer @miamiherald Fletcher, you're not my circus, not my monkey... so, bring on.</s>@miamiherald  @thekohser, do you believe that you're relevant? What facts or suggestion do you base this terrible on? Is such info filtered or esp?
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: tweet| synonyms: ['tweets', 'twitter', 'fb']
# word: laws| synonyms: ['law', 'legislation', 'regulations']
# word: last| synonyms: ['first', 'next', 'since']
# word: comment| synonyms: ['meme', 'message', 'question']
#
# Original Tweet: @RabbiZvi @Peston Read your previous tweet. Then go away with your obvious nonsense. You claim the party disciplina… https://t.co/WW7SqiS7SF</s>@memarkyb @Peston Do you trust racists to implement laws against racism? Please explain your last comment.
# Synthetic Tweet: @RabbiZvi @Peston Read your previous tweets. Then go away with your obvious nonsense. You claim the party disciplina… https://t.co/WW7SqiS7SF</s>@memarkyb @Peston Do you trust racists to implement law against racism? Please explain your first meme.
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: good| synonyms: ['great', 'well', 'better']
# word: child| synonyms: ['children', 'daughter', 'father']
# word: u| synonyms: ['b', 'r', 'm']
# word: noooo| synonyms: ['hmmmm', 'otoh', 'ummm']
# word: exiled| synonyms: ['rehabilitated', 'apologist', 'discredited']
# word: https| synonyms: ['included', 'vb', 'archive']
#
# Original Tweet: @benshapiro all good. If you rape a child Meryl Streep will give u and standing ovation but conservative noooo</s>He just had to be exiled for a decade and every movie he makes now has to be a national controversy. No problem.  https://t.co/V88FGL8Bpr
# Synthetic Tweet: @benshapiro all great. If yob rape a children Meryl Streep will give b and standing ovation bbt conservative hmmmm</s>He jbst had to be rehabilitated for a decade and every movie he makes now has to be a national controversy. No problem.  included://t.co/V88FGL8Bpr
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: people| synonyms: ['other', 'many', 'those']
# word: making| synonyms: ['made', 'makes', 'putting']
# word: factual| synonyms: ['context', 'anecdotal', 'credible']
#
# Original Tweet: @JRubinBlogger You don’t know the definition of racist! It’s your way of demeaning people who are making factual comments!</s>Announce Yerry Mina and Andre Gomes @Everton
# #DeadlineDay
# Synthetic Tweet: @JRubinBlogger You don’t know the definition of racist! It’s your way of demeaning many who are makes anecdotal comments!</s>Announce Yerry Mina and Andre Gomes @Everton
# #DeadlineDay
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: gwtiawah| synonyms: ['foreigner', 'fyi', 'ahem']
# word: accurately| synonyms: ['described', 'portrays', 'portray']
# word: greater| synonyms: ['experience', 'success', 'reward']
# word: motivation| synonyms: ['ambition', 'focus', 'routine']
# word: different| synonyms: ['other', 'many', 'same']
# word: long| synonyms: ['end', 'way', 'days']
# word: cheat| synonyms: ['cheating', 'cheats', 'lie']
# word: good| synonyms: ['great', 'well', 'better']
# word: chores| synonyms: ['routine', 'excercise', 'household']
#
# Original Tweet: @cgp42 @gwtiawah @Morgxn2001 Greed is a linguistic construct intended to divide the people. It can be defined accurately as any motivations greater than mine. Laziness would then be any motivation less than mine. We each have a different balance as long as we don’t cheat, that’s good. It’s natural law.</s>@Morgxn2001 Teach your kids about capitalism. If they get sick and can't do their chores throw them out on the street since they can't contribute any more.
# Synthetic Tweet: @cgp42 @foreigner @Morgxn2001 Greed is a linguistic construct intended to divide the people. It can be defined described as any ambitions experience than mine. Laziness would then be any ambition less than mine. We each have a other balance as end as we don’t cheating, that’s great. It’s natural law.</s>@Morgxn2001 Teach your kids about capitalism. If they get sick and can't do their routine throw them out on the street since they can't contribute any more.
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: rockhoppre| synonyms: ['gc', 'augment', 'pseudo']
# word: petty| synonyms: ['childish', 'dumb', 'disrespectful']
# word: coward| synonyms: ['cowards', 'bigot', 'heartless']
#
# Original Tweet: @rockhoppre @ABC It’s a petty and disgraceful thing to do and it takes a disgraceful coward like Trump to do it.</s>@ABC So what
# Synthetic Tweet: @pseudo @ABC It’s a disrespectful and disgraceful thing to do and it takes a disgraceful heartless like Trump to do it.</s>@ABC So what
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: sign| synonyms: ['signs', 'signing', 'deal']
# word: https| synonyms: ['included', 'vb', 'archive']
#
# Original Tweet: @BenjaminBaxterr Where do i sign?</s>say no more https://t.co/pbLQNQaN9Q
# Synthetic Tweet: @BenjaminBaxterr Where do i signs?</s>say no more included://t.co/pbLQNQaN9Q
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: fly| synonyms: ['run', 'catch', 'turn']
#
# Original Tweet: @SkyNews Do the right thing and fly them straight back to where they come from</s>RT @HFHSAthletics: Your @HF_Football game winner 👀!! https://t.co/ItgCFRR5Wk
# Synthetic Tweet: @SkyNews Do the right thing and turn them straight back to where they come from</s>RT @HFHSAthletics: Your @HF_Football game winner 👀!! https://t.co/ItgCFRR5Wk
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: official| synonyms: ['new', 'featuring', 'track']
# word: began| synonyms: ['begun', 'ended', 'continued']
#
# Original Tweet: @HuntsmanAbby @ABC @TheView @WhoopiGoldberg @JoyVBehar @sunny @MeghanMcCain #SJW at their #worst. They should be #banned from the public eye</s>It’s official! Thrilled to return to where it all began for me @ABC - running scripts, covering the overnight news… https://t.co/XkF5UBbUqm
# Synthetic Tweet: @HuntsmanAbby @ABC @TheView @WhoopiGoldberg @JoyVBehar @sunny @MeghanMcCain #SJW at their #worst. They should be #banned from the public eye</s>It’s new! Thrilled to return to where it all begun for me @ABC - running scripts, covering the overnight news… https://t.co/XkF5UBbUqm
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
#
# Original Tweet: @theage You don’t ‘battle cancer’. It happens to you. Please drop that stupid cliche</s>BREAKING Australian golfer Jarrod Lyle loses battle with cancer https://t.co/fUDeCStH3j
# Synthetic Tweet: @theage You don’t ‘battle cancer’. It happens to you. Please drop that stupid cliche</s>BREAKING Australian golfer Jarrod Lyle loses battle with cancer https://t.co/fUDeCStH3j
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: chipfranklin| synonyms: ['ect', 'ppe', 'plug']
# word: bring| synonyms: ['take', 'let', 'give']
#
# Original Tweet: @HeidiTa14818573 @chipfranklin @FoxNews Preacher of hate #chipfranklin</s>@chipfranklin @FoxNews # These illegal mothers know our laws better than us and bring their kids here on purpose so… https://t.co/KaoFCy9Cnj
# Synthetic Tweet: @HeidiTa14818573 @ppe @FoxNews Preacher of hate #ppe</s>@ppe @FoxNews # These illegal mothers know our laws better than us and let their kids here on purpose so… https://t.co/KaoFCy9Cnj
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: news| synonyms: ['bbc', 'report', 'latest']
# word: majority| synonyms: ['minority', 'unlike', 'opposed']
# word: new| synonyms: ['latest', 'check', 'first']
#
# Original Tweet: @CNNPolitics CNN fake news CNN fake news CNN fake news CNN fake news CNN fake news</s>A majority of Americans say they don't support the new plans to establish a US Space Force, according to a new CNN… https://t.co/k0GLCvhbD8
# Synthetic Tweet: @CNNPolitics CNN fake bbc CNN fake bbc CNN fake bbc CNN fake bbc CNN fake bbc</s>A minority of Americans say they don't support the latest plans to establish a US Space Force, according to a latest CNN… https://t.co/k0GLCvhbD8
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: wrong| synonyms: ['reason', 'either', 'thing']
# word: ur| synonyms: ['your', 'mine', 'my']
# word: back| synonyms: ['out', 'up', 'again']
#
# Original Tweet: @g_huskies @eiger2007 @CopeyDaniels @CNN He is wrong ur wrong too go back to Facebook u old fag</s>@eiger2007 @CopeyDaniels @CNN He isn’t wrong
# Synthetic Tweet: @g_huskies @eiger2007 @CopeyDaniels @CNN He is reason your reason too go out to Facebook u old fag</s>@eiger2007 @CopeyDaniels @CNN He isn’t reason
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: afterlife| synonyms: ['overkill', 'misery', 'rapture']
# word: atheists| synonyms: ['christians', 'catholics', 'bigots']
# word: supernatural| synonyms: ['homeland', 'cast', 'dean']
# word: maybe| synonyms: ['sure', 'guess', 'then']
# word: reject| synonyms: ['approve', 'deny', 'claim']
# word: atheistic| synonyms: ['docile', 'locality', 'leftism']
# word: awaits| synonyms: ['awaiting', 'prepares', 'begins']
# word: void| synonyms: ['fill', 'blackness', 'whereas']
# word: little| synonyms: ['bit', 'one', 'big']
# word: turn| synonyms: ['down', 'up', 'let']
#
# Original Tweet: @HalfTangible "-All that awaits you after death is the void" ❌ not believing in an afterlife is not part of atheism.  there are atheists that believe in many things including the supernatural.  You maybe referring to a subset of atheists that are religous skeptics who reject most of...</s>@Thedukeistheman According to atheistic worldview: -All that awaits you after death is the void -The universe exists for no reason -Morality has no true basis beyond what humans agree to (shockingly little and we're REALLY bad at keeping to them) -Religion must be fought at every turn
# Synthetic Tweet: @HalfTangible "-All that awaiting you after death is the fill" ❌ not believing in an overkill is not part of atheism.  there are christians that believe in many things including the homeland.  You sure referring to a subset of christians that are religous skeptics who approve most of...</s>@Thedukeistheman According to docile worldview: -All that awaiting you after death is the fill -The universe exists for no reason -Morality has no true basis beyond what humans agree to (shockingly bit and we're REALLY bad at keeping to them) -Religion must be fought at every down
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: claims| synonyms: ['denies', 'claimed', 'reports']
# word: abrahamic| synonyms: ['atheistic', 'otoh', 'merits']
# word: skeptics| synonyms: ['cynics', 'darwinism', 'historians']
# word: awaits| synonyms: ['awaiting', 'prepares', 'begins']
# word: afterlife| synonyms: ['overkill', 'misery', 'rapture']
# word: part| synonyms: ['story', 'end', 'course']
# word: things| synonyms: ['thing', 'everything', 'anything']
# word: skeptics| synonyms: ['cynics', 'darwinism', 'historians']
#
# Original Tweet: @HalfTangible …the claims made by abrahamic religions.  “-The universe exists for no reason” ❌  this is not a claim or belief of atheism so i’m going to continue this critique as if you are claiming religious skeptics carry a heavy burden.  I’ve never heard anyone claim the universe...</s>@HalfTangible "-All that awaits you after death is the void" ❌ not believing in an afterlife is not part of atheism.  there are atheists that believe in many things including the supernatural.  You maybe referring to a subset of atheists that are religous skeptics who reject most of...
# Synthetic Tweet: @HalfTangible …the denies made by atheistic religions.  “-The universe exists for no reason” ❌  this is not a claim or belief of atheism so i’m going to continue this critique as if you are claiming religious cynics carry a heavy burden.  I’ve never heard anyone claim the universe...</s>@HalfTangible "-All that awaiting you after death is the void" ❌ not believing in an overkill is not story of atheism.  there are atheists that believe in many thing including the supernatural.  You maybe referring to a subset of atheists that are religous cynics who reject most of...
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: going| synonyms: ['gonna', 'coming', 'there']
# word: never| synonyms: ['ever', 'remember', 'forget']
#
# Original Tweet: @HalfTangible …exists for no reason. So i don’t know what you are referring to.  “-Morality has no true basis beyond what humans agree to (shockingly little and we're REALLY bad at keeping to them)” somewhat ✅  I wouldn’t call that a burden though.  (cont.)</s>@HalfTangible …the claims made by abrahamic religions.  “-The universe exists for no reason” ❌  this is not a claim or belief of atheism so i’m going to continue this critique as if you are claiming religious skeptics carry a heavy burden.  I’ve never heard anyone claim the universe...
# Synthetic Tweet: @HalfTangible …exists for no reason. So i don’t know what you are referring to.  “-Morality has no true basis beyond what humans agree to (shockingly little and we're REALLY bad at keeping to them)” somewhat ✅  I wouldn’t call that a burden though.  (cont.)</s>@HalfTangible …the claims made by abrahamic religions.  “-The universe exists for no reason” ❌  this is not a claim or belief of atheism so i’m gonna to continue this critique as if you are claiming religious skeptics carry a heavy burden.  I’ve ever heard anyone claim the universe...
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: fought| synonyms: ['supported', 'fight', 'claimed']
# word: religion| synonyms: ['christianity', 'religions', 'religious']
# word: people| synonyms: ['other', 'many', 'those']
# word: learn| synonyms: ['teach', 'understand', 'learned']
# word: nice| synonyms: ['good', 'cool', 'pretty']
# word: discussion| synonyms: ['discuss', 'discussing', 'conversation']
# word: reason| synonyms: ['either', 'wrong', 'thing']
# word: humans| synonyms: ['beings', 'animals', 'species']
# word: keeping| synonyms: ['putting', 'keeps', 'kept']
# word: somewhat| synonyms: ['seemed', 'mildly', 'fairly']
# word: call| synonyms: ['tell', 'talk', 'calling']
#
# Original Tweet: @HalfTangible “-Religion must be fought at every turn” ❌  Harmful religion must be fought at every turn.  If religious people would learn to share and play nice we would’t be having this discussion.  (cont.)</s>@HalfTangible …exists for no reason. So i don’t know what you are referring to.  “-Morality has no true basis beyond what humans agree to (shockingly little and we're REALLY bad at keeping to them)” somewhat ✅  I wouldn’t call that a burden though.  (cont.)
# Synthetic Tweet: @HalfTangible “-Religion must be supported at every turn” ❌  Harmful christianity must be supported at every turn.  If religious other would teach to share and play good we would’t be having this discuss.  (cont.)</s>@HalfTangible …exists for no either. So i don’t know what you are referring to.  “-Morality has no true basis beyond what beings agree to (shockingly little and we're REALLY bad at putting to them)” seemed ✅  I wouldn’t tell that a burden though.  (cont.)
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: find| synonyms: ['where', 'see', 'anyone']
# word: also| synonyms: ['will', 'which', 'actually']
# word: insisting| synonyms: ['insist', 'suggesting', 'advocating']
# word: religion| synonyms: ['christianity', 'religions', 'religious']
# word: skeptics| synonyms: ['cynics', 'darwinism', 'historians']
# word: believe| synonyms: ['remember', 'forget', 'cant']
# word: fought| synonyms: ['supported', 'fight', 'claimed']
# word: religious| synonyms: ['christians', 'political', 'jewish']
# word: people| synonyms: ['other', 'many', 'those']
# word: would| synonyms: ['could', 'should', 'did']
# word: discussion| synonyms: ['discuss', 'discussing', 'conversation']
# word: cont| synonyms: ['fyi', 'rw', 'wi']
#
# Original Tweet: @HalfTangible “I also find it confusing that atheists can post that meme unironically while also insisting that religion is simple childish nonsense?”  …because most of us (religious skeptics) actually believe it’s nonsense.  the issue isn’t just that it’s childish it’s that it’s...</s>@HalfTangible “-Religion must be fought at every turn” ❌  Harmful religion must be fought at every turn.  If religious people would learn to share and play nice we would’t be having this discussion.  (cont.)
# Synthetic Tweet: @HalfTangible “I will where it confusing that atheists can post that meme unironically while will insist that christianity is simple childish nonsense?”  …because most of us (christians cynics) actually remember it’s nonsense.  the issue isn’t just that it’s childish it’s that it’s...</s>@HalfTangible “-Religion must be supported at every turn” ❌  Harmful christianity must be supported at every turn.  If christians other could learn to share and play nice we could’t be having this discuss.  (fyi.)
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: obviously| synonyms: ['clearly', 'apparently', 'either']
# word: captures| synonyms: ['capturing', 'exposes', 'paints']
# word: delivery| synonyms: ['service', 'deliver', 'order']
# word: throwing| synonyms: ['throw', 'putting', 'hitting']
# word: driveway| synonyms: ['plowing', 'mailbox', 'ditch']
#
# Original Tweet: @ABC He is DAMAGING the goods. He should obviously be FIRED.</s>Surveillance footage captures delivery driver throwing boxes from his van into a driveway, attempting to get the pa… https://t.co/bC4nNlSsvJ
# Synthetic Tweet: @ABC He is DAMAGING the goods. He should either be FIRED.</s>Surveillance footage paints order driver hitting boxes from his van into a ditch, attempting to get the pa… https://t.co/bC4nNlSsvJ
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
#
# Original Tweet: @FadiAlmazyad @mehdirhasan 😂😂😂😂
# I dont think your problem is missle your problem just kids
# Pls  kill  them</s>@mmd74_ @mehdirhasan https://t.co/59GQo7LFTv
# Synthetic Tweet: @FadiAlmazyad @mehdirhasan 😂😂😂😂
# I dont think your problem is missle your problem just kids
# Pls  kill  them</s>@mmd74_ @mehdirhasan https://t.co/59GQo7LFTv
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
#
# Original Tweet: @MiamiHerald He is a racist Trump boy!</s>Gol de river xd
# Synthetic Tweet: @MiamiHerald He is a racist Trump boy!</s>Gol de river xd
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: disgrace| synonyms: ['shame', 'scum', 'disgraceful']
# word: good| synonyms: ['great', 'well', 'better']
#
# Original Tweet: @DavidLammy @JuliaHB1 Lammy you’re the biggest racist I’ve heard on Twitter you’re a disgrace</s>Oh good, a white man defining what racism is and isn’t. Thanks.
# https://t.co/eRE0BWWHVv
# Synthetic Tweet: @DavidLammy @JuliaHB1 Lammy you’re the biggest racist I’ve heard on Twitter you’re a shame</s>Oh great, a white man defining what racism is and isn’t. Thanks.
# https://t.co/eRE0BWWHVv
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: deserve| synonyms: ['deserves', 'deserved', 'give']
# word: business| synonyms: ['company', 'industry', 'marketing']
# word: schools| synonyms: ['students', 'teachers', 'colleges']
# word: websites| synonyms: ['website', 'articles', 'profiles']
# word: consumers| synonyms: ['retailers', 'businesses', 'customers']
#
# Original Tweet: @realDonaldTrump Why I #RESIST  Tax Scam Bill Net Neutrality Trade Wars Pre-Existing Conditions SCOTUS Russia March For Our Lives No Tolerance ICE Environment Paris Agreement Artic/Offshore Drilling CFPB Dodd Frank Medical Marijuana StandWithPP Iran Deal Military Parade Trans Ban MeToo Taxes</s>@realDonaldTrump Republican repeal of Net Neutrality hurts us all. We deserve an open internet that is free. Same speed and access for all. Small business and schools will pay dearly. ISP’s may now decide what websites consumers can access because of their financial limitations #ReasonsToVoteBlue
# Synthetic Tweet: @realDonaldTrump Why I #RESIST  Tax Scam Bill Net Neutrality Trade Wars Pre-Existing Conditions SCOTUS Russia March For Our Lives No Tolerance ICE Environment Paris Agreement Artic/Offshore Drilling CFPB Dodd Frank Medical Marijuana StandWithPP Iran Deal Military Parade Trans Ban MeToo Taxes</s>@realDonaldTrump Republican repeal of Net Neutrality hurts us all. We deserved an open internet that is free. Same speed and access for all. Small industry and teachers will pay dearly. ISP’s may now decide what articles businesses can access because of their financial limitations #ReasonsToVoteBlue
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: wire| synonyms: ['chain', 'rope', 'plug']
#
# Original Tweet: @KellyO @maggieNYT @realDonaldTrump That's how sick in the head this mofo is.</s>“Barbed wire used properly can be a beautiful sight. “ @realDonaldTrump refers to border barrier being set up by active duty military.
# Synthetic Tweet: @KellyO @maggieNYT @realDonaldTrump That's how sick in the head this mofo is.</s>“Barbed chain used properly can be a beautiful sight. “ @realDonaldTrump refers to border barrier being set up by active duty military.
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: mongering| synonyms: ['monger', 'sensationalism', 'rhetoric']
# word: giving| synonyms: ['bringing', 'gives', 'give']
# word: platform| synonyms: ['platforms', 'enterprise', 'summit']
# word: 's| synonyms: ['is', 'the', 'and']
# word: persistence| synonyms: ['virtue', 'willingness', 'trumps']
# word: perception| synonyms: ['perspective', 'vision', 'preference']
# word: far| synonyms: ['way', 'yet', 'lot']
#
# Original Tweet: @MSNBC Michael Eric Dyson is a racist hate mongering idiot.  #MSNBC is  just as bad for giving him a platform</s>"There's the persistence of a malignant perception of black people ...  We don't have to look very far: Black peopl… https://t.co/4qYDmRphuD
# Synthetic Tweet: @MSNBC Michael Eric Dyson is a racist hate sensationalism idiot.  #MSNBC is  just as bad for gives him a enterprise</s>"Therethe the willingness of a malignant vision of black people ...  We don't have to look very yet: Black peopl… https://t.co/4qYDmRphuD
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: people| synonyms: ['other', 'many', 'those']
# word: thanks| synonyms: ['thank', 'welcome', 'cheers']
#
# Original Tweet: @FoxNews So now tax cuts are white nationalism? What the fuck is that logic? Most people ARENT WHITE.</s>Massachusetts mayor won’t drink Sam Adams beer after brewery founder thanks Trump for tax cuts https://t.co/vnbR8sCAln
# Synthetic Tweet: @FoxNews So now tax cuts are white nationalism? What the fuck is that logic? Most many ARENT WHITE.</s>Massachusetts mayor won’t drink Sam Adams beer after brewery founder welcome Trump for tax cuts https://t.co/vnbR8sCAln
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: percent| synonyms: ['minimum', 'million', 'average']
# word: 's| synonyms: ['is', 'the', 'and']
# word: handling| synonyms: ['handled', 'replacing', 'consideration']
# word: including| synonyms: ['included', 'include', 'several']
# word: https| synonyms: ['included', 'vb', 'archive']
#
# Original Tweet: @CBSNews Because Republicans are, for the most part, racist and bigoted? NEWS FLASH</s>Overall, 83 percent of Republicans approve of the president's handling of racial issues, including 44 percent who s… https://t.co/wVncBAMFSc
# Synthetic Tweet: @CBSNews Because Republicans are, for the most part, racist and bigoted? NEWS FLASH</s>Overall, 83 minimum of Republicans approve of the presidentis handled of racial issues, included 44 minimum who s… included://t.co/wVncBAMFSc
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: support| synonyms: ['supporting', 'us', 'help']
#
# Original Tweet: @NBCNews Racist Host Attacks Black Guest #MAGA #BuildTheWall #AmericaFirst #FridayFeeling</s>Jimmy Kimmel hammers Kanye West over his support for President Trump, whom West once described in a tweet as "my br… https://t.co/oVjBuSZ15a
# Synthetic Tweet: @NBCNews Racist Host Attacks Black Guest #MAGA #BuildTheWall #AmericaFirst #FridayFeeling</s>Jimmy Kimmel hammers Kanye West over his supporting for President Trump, whom West once described in a tweet as "my br… https://t.co/oVjBuSZ15a
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: eve| synonyms: ['party', 'once', 'anne']
#
# Original Tweet: @BDUTT Shame on your hate news n fake news.</s>Pistols and shooting in the national capital on the eve of Independence Day all in the name of nationalism. Shame o… https://t.co/r9n3MHpOri
# Synthetic Tweet: @BDUTT Shame on your hate news n fake news.</s>Pistols and shooting in the national capital on the once of Independence Day all in the name of nationalism. Shame o… https://t.co/r9n3MHpOri
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: lawyer| synonyms: ['attorney', 'attorneys', 'law']
# word: guilty| synonyms: ['murder', 'accused', 'charged']
# word: notable| synonyms: ['precursor', 'similar', 'astounding']
# word: https| synonyms: ['included', 'vb', 'archive']
#
# Original Tweet: @rebeccagberg Standard lawyer statement from guilty white collar criminals...</s>Rep. Chris Collins attorneys: “It is notable that even the government does not allege that Congressman Collins trad… https://t.co/eUTX3lckgZ
# Synthetic Tweet: @rebeccagberg Standard attorney statement from murder white collar criminals...</s>Rep. Chris Collins attorneys: “It is precursor that even the government does not allege that Congressman Collins trad… included://t.co/eUTX3lckgZ
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: attempt| synonyms: ['attempts', 'attempting', 'trying']
# word: distract| synonyms: ['convince', 'convincing', 'undermine']
#
# Original Tweet: @kylegriffin1 Just another attempt by @realDonaldTrump to distract us from the “Real News” of his felonious a*s. No… https://t.co/gb6KjOClBo</s>Larry Kudlow says the W.H. is "taking a look" at whether Google and its search engine should be regulated after Tru… https://t.co/bxTi5Z8tWE
# Synthetic Tweet: @kylegriffin1 Just another attempts by @realDonaldTrump to convince us from the “Real News” of his felonious a*s. No… https://t.co/gb6KjOClBo</s>Larry Kudlow says the W.H. is "taking a look" at whether Google and its search engine should be regulated after Tru… https://t.co/bxTi5Z8tWE
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: lowlife| synonyms: ['asswipe', 'sickos', 'classless']
# word: looks| synonyms: ['look', 'looked', 'pretty']
# word: every| synonyms: ['thing', 'whole', 'another']
# word: response| synonyms: ['responses', 'example', 'answer']
#
# Original Tweet: @maggieNYT @MalcolmNance @realDonaldTrump Well he knows what a lowlife is.  One looks back at him every morning as he shaves.</s>In the press pool today, I asked @realDonaldTrump if he had a response to Omarosa. He held hand to mouth, as if to… https://t.co/hWA0O9BHcg
# Synthetic Tweet: @maggieNYT @MalcolmNance @realDonaldTrump Well he knows what a asswipe is.  One look back at him thing morning as he shaves.</s>In the press pool today, I asked @realDonaldTrump if he had a responses to Omarosa. He held hand to mouth, as if to… https://t.co/hWA0O9BHcg
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: arm| synonyms: ['hand', 'chest', 'leg']
# word: students| synonyms: ['student', 'teachers', 'schools']
#
# Original Tweet: @RitchieJodi @MailOnline Inject poison in arm kill yourself thank you</s>University offers students online guide to taking heroin https://t.co/c5g1MJHOp3 @MailOnline
# Synthetic Tweet: @RitchieJodi @MailOnline Inject poison in hand kill yourself thank you</s>University offers student online guide to taking heroin https://t.co/c5g1MJHOp3 @MailOnline
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: killing| synonyms: ['kill', 'kills', 'killed']
# word: self| synonyms: ['yourself', 'handle', 'fool']
# word: confessed| synonyms: ['claimed', 'succeeded', 'stated']
# word: chief| synonyms: ['vp', 'says', 'spokesman']
# word: anything| synonyms: ['something', 'nothing', 'either']
# word: https| synonyms: ['included', 'vb', 'archive']
#
# Original Tweet: @ABC @jonkarl @realDonaldTrump is a democracy killing self confessed molester in chief</s>"Why won't you say anything about John McCain?"
#
# ...
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: either| synonyms: ['unless', 'guess', 'obviously']
# word: expose| synonyms: ['exposing', 'deny', 'allow']
# word: confidante| synonyms: ['staffer', 'otoh', 'nihad']
# word: govt| synonyms: ['government', 'congress', 'gov']
#
# Original Tweet: @IngrahamAngle @NBCNews Unfortunately you can’t believe anyone in this White House.  Or anything you say either. Zero credibility.</s>This is an exceedingly straightforward expose of Omarosa by her closest confidante in govt.  Will ⁦⁦@NBCNews⁩ do a… https://t.co/XpHfsfj7mO
# Synthetic Tweet: @IngrahamAngle @NBCNews Unfortunately you can’t believe anyone in this White House.  Or anything you say unless. Zero credibility.</s>This is an exceedingly straightforward exposing of Omarosa by her closest staffer in government.  Will ⁦⁦@NBCNews⁩ do a… https://t.co/XpHfsfj7mO
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: also| synonyms: ['will', 'which', 'actually']
# word: close| synonyms: ['way', 'either', 'least']
# word: said| synonyms: ['told', 'thought', 'did']
#
# Original Tweet: @maggieNYT But perhaps he is also at his most stupid.</s>When Trump is cornered, he is at his most dangerous, as several people close to him have said. During "Access Holly… https://t.co/RVc5ttZqwF
# Synthetic Tweet: @maggieNYT But perhaps he is will at his most stupid.</s>When Trump is cornered, he is at his most dangerous, as several people way to him have told. During "Access Holly… https://t.co/RVc5ttZqwF
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: lot| synonyms: ['alot', 'much', 'many']
# word: mourners| synonyms: ['schoolchildren', 'allege', 'staffers']
# word: https| synonyms: ['included', 'vb', 'archive']
#
# Original Tweet: @itvnews Bomb the lot@of@them</s>Thousands of mourners in Pakistan gather for the funeral of a prominent cleric known as the 'Father of the Taliban'… https://t.co/1H07ozjNFI
# Synthetic Tweet: @itvnews Bomb the many@of@them</s>Thousands of staffers in Pakistan gather for the funeral of a prominent cleric known as the 'Father of the Taliban'… archive://t.co/1H07ozjNFI
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: dementia| synonyms: ['autism', 'illness', 'patients']
# word: compared| synonyms: ['unlike', 'except', 'besides']
# word: groups| synonyms: ['members', 'organizations', 'group']
#
# Original Tweet: @MailOnline This is racist 😂</s>Black people face a greater risk of dementia compared to other ethnic groups - and those from Asian backgrounds are… https://t.co/jbeCVXPaBr
# Synthetic Tweet: @MailOnline This is racist 😂</s>Black people face a greater risk of illness except to other ethnic organizations - and those from Asian backgrounds are… https://t.co/jbeCVXPaBr
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: fake| synonyms: ['stupid', 'famous', 'gay']
# word: https| synonyms: ['included', 'vb', 'archive']
#
# Original Tweet: @UforicH @Ganulvian @SunLover749 @USATODAY Lol here comes the cult "Wikipedia is fake news" bs. Trump supporters sh… https://t.co/3c19rSW6N9</s>@robespierre188 @Ganulvian @SunLover749 @USATODAY Argue what? You’re comparing adults to children, you’re justifyin… https://t.co/mAf9tvIHGk
# Synthetic Tweet: @UforicH @Ganulvian @SunLover749 @USATODAY Lol here comes the cult "Wikipedia is stupid news" bs. Trump supporters sh… included://t.co/3c19rSW6N9</s>@robespierre188 @Ganulvian @SunLover749 @USATODAY Argue what? You’re comparing adults to children, you’re justifyin… included://t.co/mAf9tvIHGk
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: large| synonyms: ['small', 'medium', 'huge']
# word: kids| synonyms: ['children', 'kid', 'babies']
# word: fear| synonyms: ['afraid', 'enemy', 'sight']
# word: hate| synonyms: ['stupid', 'swear', 'why']
# word: help| synonyms: ['need', 'helping', 'please']
# word: correct| synonyms: ['spell', 'incorrect', 'wrong']
# word: mmpadellan| synonyms: ['mikan', 'nitz', 'rakin']
# word: matter| synonyms: ['whatever', 'regardless', 'reason']
#
# Original Tweet: @laurabh07712 @mmpadellan The grandfather and father in the story are a large part of the problem. Stop teaching your kids to fear and hate the police they will stop acting the way they do around the police and that will change the way the police see them and help correct the problem when there is one.</s>@mmpadellan Black lives matter! #BLM  https://t.co/ptIEkQDwD1
# Synthetic Tweet: @laurabh07712 @mikan The grandfather and father in the story are a small part of the problem. Stop teaching your children to afraid and stupid the police they will stop acting the way they do around the police and that will change the way the police see them and need spell the problem when there is one.</s>@mikan Black lives whatever! #BLM  https://t.co/ptIEkQDwD1
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: system| synonyms: ['systems', 'device', 'tool']
# word: white| synonyms: ['black', 'blue', 'green']
# word: save| synonyms: ['saving', 'bring', 'send']
#
# Original Tweet: @CapehartJ #RichWhiteLivesMatter
#
# Fox News constant attack on justice system and law enforcement to defend its precious white Billionaire</s>Stop wondering who is going to save us. YOU are the one to save us. https://t.co/UpjQuLic5G
# Synthetic Tweet: @CapehartJ #RichWhiteLivesMatter
#
# Fox News constant attack on justice systems and law enforcement to defend its precious black Billionaire</s>Stop wondering who is going to saving us. YOU are the one to saving us. https://t.co/UpjQuLic5G
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: say| synonyms: ['tell', 'mean', 'know']
# word: 's| synonyms: ['is', 'the', 'and']
# word: insured| synonyms: ['taxed', 'insure', 'defective']
# word: high| synonyms: ['low', 'bad', 'down']
# word: minimum| synonyms: ['wage', 'cost', 'budget']
# word: universal| synonyms: ['digital', 'audio', 'electronic']
# word: democratic| synonyms: ['republican', 'democrat', 'democracy']
# word: want| synonyms: ['need', 'if', 'wanna']
#
# Original Tweet: @prageru Stop lying, @prageru. If you don't want Universal Healthcare for all Americans, then fine. Just say that. Stop pretending like Venezuela's economy failed because of socialism.   Real American patriots want healthy &amp; insured American people.</s>@prageru Because not a single one of those countries gave their citizens a high minimum wage with universal healthcare for all, which is all democratic socialists want. And THAT is currently working in  🇨🇦 Canada  🇩🇰 Denmark  🇩🇪 Germany  🇳🇴 Norway  🇸🇪 Sweden  🇦🇺 Australia  🇨🇭Switzerland
# Synthetic Tweet: @prageru Stop lying, @prageru. If you don't need Universal Healthcare for all Americans, then fine. Just tell that. Stop pretending like Venezuelais economy failed because of socialism.   Real American patriots need healthy &amp; taxed American people.</s>@prageru Because not a single one of those countries gave their citizens a low wage wage with digital healthcare for all, which is all republican socialists need. And THAT is currently working in  🇨🇦 Canada  🇩🇰 Denmark  🇩🇪 Germany  🇳🇴 Norway  🇸🇪 Sweden  🇦🇺 Australia  🇨🇭Switzerland
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: possible| synonyms: ['impossible', 'important', 'force']
#
# Original Tweet: @helenzille @Lazola_Ndamase How is it possible for a right winger to claim that she fought for freedom?</s>@Lazola_Ndamase How is it possible for any single person to be this idiotic and clueless?
# Synthetic Tweet: @helenzille @Lazola_Ndamase How is it impossible for a right winger to claim that she fought for freedom?</s>@Lazola_Ndamase How is it impossible for any single person to be this idiotic and clueless?
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: helenzille| synonyms: ['calif', 'jztfwkoj0f', 'hmmmm']
# word: realities| synonyms: ['robots', 'aspects', 'visions']
#
# Original Tweet: @ntsakosnr0 @helenzille @Lazola_Ndamase You claim to be an historian and writer, but obviously you have no idea of the realities that face you. We need some real right-wingers to show you how moderate @helenzille really is. #DA #EFF #ANC #ActionStations</s>@helenzille @Lazola_Ndamase How is it possible for a right winger to claim that she fought for freedom?
# Synthetic Tweet: @ntsakosnr0 @calif @Lazola_Ndamase You claim to be an historian and writer, but obviously you have no idea of the robots that face you. We need some real right-wingers to show you how moderate @calif really is. #DA #EFF #ANC #ActionStations</s>@calif @Lazola_Ndamase How is it possible for a right winger to claim that she fought for freedom?
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: thinking| synonyms: ['talking', 'wondering', 'instead']
# word: ntsakosnr0| synonyms: ['wikipedia', 'gibson', 'huffpost']
# word: obviously| synonyms: ['clearly', 'apparently', 'either']
# word: need| synonyms: ['take', 'give', 'get']
# word: helenzille| synonyms: ['calif', 'jztfwkoj0f', 'hmmmm']
# word: really| synonyms: ['think', 'actually', 'how']
#
# Original Tweet: @FM_ZEE @helenzille @Lazola_Ndamase I have no time for lazy thinking right wingers</s>@ntsakosnr0 @helenzille @Lazola_Ndamase You claim to be an historian and writer, but obviously you have no idea of the realities that face you. We need some real right-wingers to show you how moderate @helenzille really is. #DA #EFF #ANC #ActionStations
# Synthetic Tweet: @FM_ZEE @calif @Lazola_Ndamase I have no time for lazy talking right wingers</s>@wikipedia @calif @Lazola_Ndamase You claim to be an historian and writer, but clearly you have no idea of the realities that face you. We take some real right-wingers to show you how moderate @calif think is. #DA #EFF #ANC #ActionStations
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: lazy| synonyms: ['tired', 'usual', 'sick']
# word: right| synonyms: ['now', 'though', 'again']
# word: wingers| synonyms: ['spaniards', 'arsenals', 'leftists']
#
# Original Tweet: @ntsakosnr0 @FM_ZEE @helenzille @Lazola_Ndamase And you have no time for thinking, apparently.</s>@FM_ZEE @helenzille @Lazola_Ndamase I have no time for lazy thinking right wingers
# Synthetic Tweet: @ntsakosnr0 @FM_ZEE @helenzille @Lazola_Ndamase And you have no time for thinking, apparently.</s>@FM_ZEE @helenzille @Lazola_Ndamase I have no time for tired thinking now spaniards
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: news| synonyms: ['bbc', 'report', 'latest']
# word: 's| synonyms: ['is', 'the', 'and']
#
# Original Tweet: @nytimes you are lying news ...</s>Turkey's banks are pulling back on credit. Power plants have shut down. And a pharmacist worries he won't be able t… https://t.co/1NHnK9hdqZ
# Synthetic Tweet: @nytimes you are lying report ...</s>Turkeythe banks are pulling back on credit. Power plants have shut down. And a pharmacist worries he won't be able t… https://t.co/1NHnK9hdqZ
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: washingtonpost| synonyms: ['usatoday', 'nytimes', 'skysportsnews']
# word: disrespectful| synonyms: ['ignorant', 'childish', 'pathetic']
# word: despite| synonyms: ['continued', 'continuing', 'however']
# word: views| synonyms: ['view', 'posts', 'shows']
#
# Original Tweet: @queloquecontigo @washingtonpost Any and all Americans should!  Trump is a national disgrace.</s>@washingtonpost Wow that’s disrespectful. McCain served this country to the very end despite his policial views and… https://t.co/xOIBT6vtX8
# Synthetic Tweet: @queloquecontigo @nytimes Any and all Americans should!  Trump is a national disgrace.</s>@nytimes Wow that’s childish. McCain served this country to the very end continuing his policial posts and… https://t.co/xOIBT6vtX8
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: gone| synonyms: ['gon', 'gotta', 'gonna']
# word: murdered| synonyms: ['killed', 'tortured', 'attacked']
# word: https| synonyms: ['included', 'vb', 'archive']
#
# Original Tweet: @RealCandaceO @CNN @realDonaldTrump Candace has gone full blown white nationalist. 😂😂</s>White farmers are being murdered by the South African government. As we learned from Zimbabwe, murdering whites eve… https://t.co/qjSBvjbxRR
# Synthetic Tweet: @RealCandaceO @CNN @realDonaldTrump Candace has gon full blown white nationalist. 😂😂</s>White farmers are being killed by the South African government. As we learned from Zimbabwe, murdering whites eve… included://t.co/qjSBvjbxRR
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: offends| synonyms: ['frankly', 'mocking', 'offended']
# word: coherent| synonyms: ['construct', 'convoluted', 'rational']
# word: someone| synonyms: ['anyone', 'something', 'else']
#
# Original Tweet: @Nugoomi @afneil I don't hate them, women's oppression offends me.
#
# But I guess you don't have a coherent argument to offer. bye.</s>@oaedoel @afneil *sighs ... as pointless as ever trying to reason with people who just need to find someone to hate
#
# Bye 👋🏼
# Synthetic Tweet: @Nugoomi @afneil I don't hate them, women's oppression mocking me.
#
# But I guess you don't have a convoluted argument to offer. bye.</s>@oaedoel @afneil *sighs ... as pointless as ever trying to reason with people who just need to find something to hate
#
# Bye 👋🏼
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: looks| synonyms: ['look', 'looked', 'pretty']
# word: lol| synonyms: ['lmao', 'yeah', 'wtf']
#
# Original Tweet: @JuliaHB1 Mrs dick looks into BJ lol</s>Welcome to Britain in 2018. https://t.co/yY6INKUUhN
# Synthetic Tweet: @JuliaHB1 Mrs dick looked into BJ yeah</s>Welcome to Britain in 2018. https://t.co/yY6INKUUhN
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: preacher| synonyms: ['pastor', 'politician', 'jewish']
#
# Original Tweet: @RT_com Hate preacher</s>Ex-English Defence Leader #TommyRobinson has had his #Instagram account removed https://t.co/UMa3rQvAWv
# Synthetic Tweet: @RT_com Hate pastor</s>Ex-English Defence Leader #TommyRobinson has had his #Instagram account removed https://t.co/UMa3rQvAWv
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: mine| synonyms: ['yours', 'mines', 'either']
# word: folks| synonyms: ['ppl', 'yall', 'everybody']
#
# Original Tweet: @ItsKrissy @kenny_token @Kanisha1Jackson And I stand by mine that you are the most immature and childish person in this thread.</s>@TheKidE85 @Roscoe_AlGhul @Kanisha1Jackson That one of those “black folks can’t be racist” memes? The white tears one? lol. No tears here. It’s just ignorant &amp; sad.
# Synthetic Tweet: @ItsKrissy @kenny_token @Kanisha1Jackson And I stand by mines that you are the most immature and childish person in this thread.</s>@TheKidE85 @Roscoe_AlGhul @Kanisha1Jackson That one of those “black yall can’t be racist” memes? The white tears one? lol. No tears here. It’s just ignorant &amp; sad.
# Artificial example created
# New Tweet ----
#
# Words and Syns:
#
# word: stupid| synonyms: ['dumb', 'mad', 'damn']
# word: literally| synonyms: ['basically', 'probably', 'actually']
# word: thread| synonyms: ['sheet', 'medium', 'archive']
#
# Original Tweet: @SpiritedIdeals @kenny_token @Kanisha1Jackson @Yourself Or because it’s a stupid thing to say. Also threads and jumping in is literally the point of Twitter.</s>@ItsKrissy @kenny_token @Kanisha1Jackson And I stand by mine that you are the most immature and childish person in this thread.
# Synthetic Tweet: @SpiritedIdeals @kenny_token @Kanisha1Jackson @Yourself Or because it’s a dumb thing to say. Also sheets and jumping in is basically the point of Twitter.</s>@ItsKrissy @kenny_token @Kanisha1Jackson And I stand by mine that you are the most immature and childish person in this sheet.
# Artificial example created
#
# 355 synthetic tweets manufactured from 355 positive examples

# %% [markdown]
# Below are functions for additional over/undersampling beyond the artificial oversampling above. We choose to underesample in addition to the oversampling above.

# %%
 def over_sample(train_df, baseline = False):

  if baseline == False:
    pos_texts = train_df[train_df.labels == 'pos']
    neg_texts = train_df[train_df.labels == 'neg']
  elif baseline == True:
    pos_texts = train_df[train_df.labels == 1]
    neg_texts = train_df[train_df.labels == 0]
  
  count_class_neg = neg_texts.shape[0]

  print('Minority class has {} rows'.format(pos_texts.shape[0]))
  print('Majority class has {} rows'.format(count_class_neg))
  print('{} new rows created'.format(count_class_neg - pos_texts.shape[0]))

  pos_texts_over = pos_texts.sample(count_class_neg, replace=True)

  texts_oversampled = pd.concat([neg_texts, pos_texts_over], axis=0)

  #Randomize before returning
  return texts_oversampled.sample(frac=1)

def under_sample(train_df, baseline = False):

  if baseline == False:
    pos_texts = train_df[train_df.labels == 'pos']
    neg_texts = train_df[train_df.labels == 'neg']
  elif baseline == True:
    pos_texts = train_df[train_df.labels == 1]
    neg_texts = train_df[train_df.labels == 0]

  count_class_pos = pos_texts.shape[0]

  print('Minority class has {} rows'.format(count_class_pos))
  print('Majority class has {} rows'.format(neg_texts.shape[0]))
  print('{} new rows removed'.format(neg_texts.shape[0] - count_class_pos))

  neg_texts_over = neg_texts.sample(count_class_pos, replace=True)

  texts_undersampled = pd.concat([pos_texts, neg_texts_over], axis=0)

  #Randomize before returning  
  return texts_undersampled.sample(frac=1)

# %%
# Undersampling our train corpus with synthetic data
corpus_formatted_train_w_synthetic_us = over_sample(corpus_formatted_train_w_synthetic)

# Standard oversampling for our final model for comparison
corpus_formatted_train_standard_os = over_sample(corpus_formatted_train)

# Standard oversampling for our baslilne model for comparison
corpus_formatted_train_baseline_standard_os = over_sample(corpus_formatted_train_baseline, baseline= True)
# Out:
# Minority class has 710 rows
# Majority class has 857 rows
# 147 new rows created
# Minority class has 355 rows
# Majority class has 857 rows
# 502 new rows created
# Minority class has 355 rows
# Majority class has 857 rows
# 502 new rows created

# %%
corpus_formatted_train_w_synthetic_us.to_csv("/content/drive/My Drive/data_twitter/train_data_w_ae_us_" + str(today) + "_v" + version + ".csv",
                                          index = False)

# %% [markdown]
# #### Train Corpus with Standard Oversampling for Comparison

# %%
corpus_formatted_train_standard_os.to_csv("/content/drive/My Drive/data_twitter/train_data_standard_os_" + str(today) + "_v" + version + ".csv",
                                          index = False)

# %% [markdown]
# #### Standard Oversampling on Baseline Corpus

# %%
corpus_formatted_train_baseline_standard_os.to_csv("/content/drive/My Drive/data_twitter/train_data_baseline_" + str(today) + "_v" + version + ".csv",
                            index = False)

# %%
corpus_train = pd.read_csv("/content/drive/My Drive/data_twitter/train_data_w_ae_us_2021-04-04_v1.csv")

# %% [markdown]
# Additional Texting

# %%
corpus_train['texts2'] = corpus_train['texts'].apply(lambda x: x.split('</s>')[0])

# %%
corpus_train['texts3'] = corpus_train['texts'].apply(lambda x: x.replace('</s>', ' '))

# %%
corpus_train_1 = corpus_train.drop(columns=['texts', 'texts3'])
corpus_train_1 = corpus_train_1.rename(columns = {'texts2': 'texts'})
corpus_train_1.to_csv("/content/drive/My Drive/data_twitter/train_data_singleconvoo_" + str(today) + "_v" + version + ".csv",
                            index = False)

# %%
corpus_train_2 = corpus_train.drop(columns=['texts', 'texts2'])
corpus_train_2 = corpus_train_2.rename(columns = {'texts3': 'texts'})
corpus_train_2.to_csv("/content/drive/My Drive/data_twitter/train_data_nosplitconvo_" + str(today) + "_v" + version + ".csv",
                            index = False)
